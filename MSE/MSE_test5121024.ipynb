# %%
# https://github.com/Lay4U/CapstOne/blob/master/python/.ipynb_checkpoints/test_ver_3_test-checkpoint.ipynb
# https://github.com/Lay4U/CapstOne/tree/master/python/test_plt

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

import winsound

# %%
df = pd.read_csv('final_data.csv', encoding='utf-8')
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#                  날짜   호선   역번호   역명     인원
# 0        2020-01-01  1호선   150  서울역  121.0
# 1        2020-01-01  1호선   150  서울역 -672.0
# 2        2020-01-01  1호선   150  서울역 -515.0
# 3        2020-01-01  1호선   150  서울역 -269.0
# 4        2020-01-01  1호선   150  서울역 -771.0
# ...             ...  ...   ...  ...    ...
# 3662777  2023-10-31  8호선  2828  남위례 -535.0
# 3662778  2023-10-31  8호선  2828  남위례 -160.0
# 3662779  2023-10-31  8호선  2828  남위례 -133.0
# 3662780  2023-10-31  8호선  2828  남위례 -159.0
# 3662781  2023-10-31  8호선  2828  남위례 -165.0
#
# [3662782 rows x 5 columns]

# %%
s = df['역명']
s
# Out:
# 0          서울역
# 1          서울역
# 2          서울역
# 3          서울역
# 4          서울역
#           ...
# 3662777    남위례
# 3662778    남위례
# 3662779    남위례
# 3662780    남위례
# 3662781    남위례
# Name: 역명, Length: 3662782, dtype: object

# %%
s = list(set(s))
s
# Out:
# ['미아사거리',
#  '서울대입구(관악구청)',
#  '화곡',
#  '오목교(목동운동장앞)',
#  '청구',
#  '용답',
#  '이태원',
#  '암사',
#  '상도',
#  '용마산(용마폭포공원)',
#  '상왕십리',
#  '방화',
#  '양천구청',
#  '내방',
#  '하남검단산',
#  '올림픽공원(한국체대)',
#  '중계',
#  '효창공원앞',
#  '상봉(시외버스터미널)',
#  '연신내',
#  '신흥',
#  '역삼',
#  '안암(고대병원앞)',
#  '중화',
#  '매봉',
#  '삼성(무역센터)',
#  '역촌',
#  '가락시장',
#  '동대문',
#  '개화산',
#  '동대입구',
#  '교대(법원.검찰청)',
#  '총신대입구(이수)',
#  '목동',
#  '천왕',
#  '단대오거리',
#  '미사',
#  '강일',
#  '용마산',
#  '수서',
#  '광흥창(서강)',
#  '문래',
#  '합정',
#  '당고개',
#  '어린이대공원(세종대)',
#  '발산',
#  '둔촌동',
#  '장지',
#  '경복궁(정부서울청사)',
#  '지축',
#  '동대문역사문화공원(DDP)(DDP)',
#  '충정로(경기대입구)',
#  '도곡',
#  '잠원',
#  '남위례',
#  '구파발',
#  '구의(광진구청)',
#  '신정네거리',
#  '영등포구청',
#  '장한평',
#  '굴포천',
#  '군자(능동)',
#  '봉천',
#  '삼산체육관',
#  '우장산',
#  '응암',
#  '길음',
#  '상수',
#  '쌍문',
#  '몽촌토성(평화의문)',
#  '압구정',
#  '수락산',
#  '숭실대입구(살피재)',
#  '창동',
#  '보라매',
#  '강동',
#  '부평구청',
#  '오금',
#  '명동',
#  '옥수',
#  '구산',
#  '안국',
#  '광명사거리',
#  '제기동',
#  '회현(남대문시장)',
#  '남구로',
#  '고속터미널',
#  '을지로3가',
#  '봉화산(서울의료원)',
#  '잠실나루',
#  '새절(신사)',
#  '김포공항',
#  '신정(은행정)',
#  '답십리',
#  '남성',
#  '하남풍산',
#  '석계',
#  '신대방',
#  '사당',
#  '월드컵경기장(성산)',
#  '수진',
#  '행당',
#  '낙성대',
#  '마포구청',
#  '홍대입구',
#  '신촌',
#  '거여',
#  '종로5가',
#  '강남',
#  '돌곶이',
#  '중곡',
#  '종합운동장',
#  '여의나루',
#  '보문',
#  '낙성대(강감찬)',
#  '영등포시장',
#  '불광',
#  '까치산',
#  '태릉입구',
#  '이수',
#  '종각',
#  '송정',
#  '공덕',
#  '뚝섬',
#  '신내',
#  '천호(풍납토성)',
#  '신풍',
#  '문정',
#  '산성',
#  '왕십리(성동구청)',
#  '녹사평(용산구청)',
#  '충무로',
#  '광화문(세종문화회관)',
#  '용두(동대문구청)',
#  '양평',
#  '학동',
#  '가산디지털단지',
#  '신대방삼거리',
#  '버티고개',
#  '온수(성공회대입구)',
#  '까치울',
#  '논현',
#  '을지로4가',
#  '강동구청',
#  '이대',
#  '신길',
#  '명일',
#  '신용산',
#  '신중동',
#  '서대문',
#  '망원',
#  '광나루(장신대)',
#  '석촌',
#  '구로디지털단지',
#  '대치',
#  '청량리(서울시립대입구)',
#  '남부터미널(예술의전당)',
#  '도봉산',
#  '을지로입구',
#  '공릉(서울과학기술대)',
#  '먹골',
#  '시청',
#  '강변(동서울터미널)',
#  '증산(명지대앞)',
#  '모란',
#  '길동',
#  '양재(서초구청)',
#  '동대문역사문화공원(DDP)',
#  '금호',
#  '고려대(종암)',
#  '상일동',
#  '홍제',
#  '삼각지',
#  '미아(서울사이버대학)',
#  '상동',
#  '아현',
#  '여의도',
#  '종로3가',
#  '잠실새내',
#  '무악재',
#  '도림천',
#  '동묘앞',
#  '아차산(어린이대공원후문)',
#  '건대입구',
#  '노원',
#  '신사',
#  '동작(현충원)',
#  '신금호',
#  '고덕',
#  '신답',
#  '한강진',
#  '경찰병원',
#  '상계',
#  '반포',
#  '마포',
#  '마천',
#  '방배',
#  '녹번',
#  '청담',
#  '대흥(서강대앞)',
#  '이촌(국립중앙박물관)',
#  '한성대입구(삼선교)',
#  '부천종합운동장',
#  '월곡(동덕여대)',
#  '면목',
#  '성수',
#  '대청',
#  '마곡',
#  '상월곡(한국과학기술연구원)',
#  '디지털미디어시티',
#  '하남시청(덕풍·신장)',
#  '일원',
#  '수유(강북구청)',
#  '혜화',
#  '학여울',
#  '하계',
#  '잠실(송파구청)',
#  '뚝섬유원지',
#  '화랑대(서울여대입구)',
#  '부천시청',
#  '남태령',
#  '복정',
#  '남한산성입구(성남법원.검찰청)',
#  '신도림',
#  '선릉',
#  '강남구청',
#  '독립문',
#  '서울역',
#  '장암',
#  '개롱',
#  '창신',
#  '서초',
#  '애오개',
#  '한양대',
#  '신설동',
#  '성신여대입구(돈암)',
#  '숙대입구(갈월)',
#  '방이',
#  '춘의',
#  '마들',
#  '마장',
#  '대림(구로구청)',
#  '사가정',
#  '신림',
#  '장승배기',
#  '철산',
#  '당산',
#  '독바위',
#  '신당',
#  '굽은다리(강동구민회관앞)',
#  '송파',
#  '약수']

# %%
len(s)
# Out:
# 252

# %%
data1 = df[df['역명']=='서울역']
data1
# Out:
#                 날짜   호선  역번호   역명      인원
# 0       2020-01-01  1호선  150  서울역   121.0
# 1       2020-01-01  1호선  150  서울역  -672.0
# 2       2020-01-01  1호선  150  서울역  -515.0
# 3       2020-01-01  1호선  150  서울역  -269.0
# 4       2020-01-01  1호선  150  서울역  -771.0
# ...            ...  ...  ...  ...     ...
# 2872073 2022-12-30  1호선  150  서울역   434.0
# 2872074 2022-12-30  1호선  150  서울역  1126.0
# 2872075 2022-12-30  1호선  150  서울역  1037.0
# 2872076 2022-12-30  1호선  150  서울역   884.0
# 2872077 2022-12-30  1호선  150  서울역   543.0
#
# [20615 rows x 5 columns]

# %%
def create_dataset(signal_data, look_back=1):
    dataX, dataY = [], []
    for i in range(len(signal_data) - look_back):
        dataX.append(signal_data[i:(i + look_back), 0])
        dataY.append(signal_data[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

look_back = 7

# %%
data = data1['인원']
data = data.values.astype('float32')
data = data.reshape(len(data), 1)

scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

train_size = int(len(data) * 0.80)
test_size = len(data) - train_size

train = data[0:train_size]
test = data[train_size:len(data)]
x_train, y_train = create_dataset(train, look_back)
x_test, y_test = create_dataset(test, look_back)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

model = Sequential()
model.add(LSTM(512, input_shape=(None, 1), return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(1024, input_shape=(None, 1)))
model.add(Dropout(0.3))
model.add(Dense(1))
name = "lb7+lstm512+lstm1024.jpg"
model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['accuracy'])
model.summary()
hist = model.fit(x_train, y_train, epochs=10, batch_size=16)
p = model.predict(x_test)

plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'p'], loc='upper right')
plt.title(mean_squared_error(y_test, p))
plt.savefig(name)
plt.clf()
print(mean_squared_error(y_test, p))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, None, 512)         1052672
#
#  dropout (Dropout)           (None, None, 512)         0
#
#  lstm_1 (LSTM)               (None, 1024)              6295552
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense (Dense)               (None, 1)                 1025
#
# =================================================================
# Total params: 7349249 (28.04 MB)
# Trainable params: 7349249 (28.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 1031/1031 [==============================] - 202s 191ms/step - loss: 0.0087 - accuracy: 0.0000e+00
# Epoch 2/10
# 1031/1031 [==============================] - 203s 197ms/step - loss: 0.0058 - accuracy: 6.0661e-05
# Epoch 3/10
# 1031/1031 [==============================] - 204s 198ms/step - loss: 0.0053 - accuracy: 6.0661e-05
# Epoch 4/10
# 1031/1031 [==============================] - 201s 195ms/step - loss: 0.0051 - accuracy: 6.0661e-05
# Epoch 5/10
# 1031/1031 [==============================] - 202s 196ms/step - loss: 0.0050 - accuracy: 6.0661e-05
# Epoch 6/10
# 1031/1031 [==============================] - 201s 195ms/step - loss: 0.0049 - accuracy: 6.0661e-05
# Epoch 7/10
# 1031/1031 [==============================] - 201s 195ms/step - loss: 0.0048 - accuracy: 6.0661e-05
# Epoch 8/10
# 1031/1031 [==============================] - 201s 195ms/step - loss: 0.0048 - accuracy: 6.0661e-05
# Epoch 9/10
# 1031/1031 [==============================] - 204s 198ms/step - loss: 0.0047 - accuracy: 6.0661e-05
# Epoch 10/10
# 1031/1031 [==============================] - 201s 195ms/step - loss: 0.0047 - accuracy: 6.0661e-05
# 129/129 [==============================] - 7s 45ms/step
# 0.0056059477

# %%
trainPredict = model.predict(x_train)
testPredict = model.predict(x_test)

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([y_test])

trainPredictPlot = np.empty_like(data)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

testPredictPlot = np.empty_like(data)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2):len(data)+2, :] = testPredict

plt.plot(scaler.inverse_transform(data), label='Original Data')
plt.plot(trainPredictPlot, label='Train Predictions')
plt.plot(testPredictPlot, label='Test Predictions')

plt.legend()
plt.show()
# Out:
# 516/516 [==============================] - 21s 41ms/step
# 129/129 [==============================] - 6s 43ms/step

# %%
plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'p'], loc='upper right')
plt.title(mean_squared_error(y_test, p))
# plt.savefig(datetime.datetime.now())
plt.show()
print(mean_squared_error(y_test, p))
# Out:
# 0.0056059477
